# %% [markdown]
# ### ライブラリのインストール

# %%
# !pip install --upgrade langchain langchain-openai langgraph pydantic python-dotenv faiss-cpu
# Out:
# Requirement already satisfied: langchain in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-openai in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (0.3.33)
# Requirement already satisfied: langgraph in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (0.6.7)
# Collecting langgraph
#   Downloading langgraph-0.6.8-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: pydantic in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (2.11.9)
# Requirement already satisfied: python-dotenv in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (1.1.1)
# Requirement already satisfied: faiss-cpu in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (1.12.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain) (0.3.76)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain) (0.4.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydantic) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\user\appdata\roaming\python\python310\site-packages (from pydantic) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydantic) (0.4.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: packaging>=23.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: openai<2.0.0,>=1.104.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-openai) (1.107.2)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\user\appdata\roaming\python\python310\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.104.2->langchain-openai) (1.3.0)
# Requirement already satisfied: httpcore==1.* in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.104.2->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.104.2->langchain-openai) (0.16.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2025.7.34)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langgraph) (2.1.1)
# Requirement already satisfied: langgraph-prebuilt<0.7.0,>=0.6.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langgraph) (0.6.4)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langgraph) (0.2.6)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph) (1.10.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.11.3)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langsmith>=0.1.17->langchain) (0.24.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python310\site-packages (from tqdm>4->openai<2.0.0,>=1.104.2->langchain-openai) (0.4.6)
# Downloading langgraph-0.6.8-py3-none-any.whl (154 kB)
# Installing collected packages: langgraph
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 0.6.7
#     Uninstalling langgraph-0.6.7:
#       Successfully uninstalled langgraph-0.6.7
# Successfully installed langgraph-0.6.8

# %%
# !pip install -U langchain-community
# Out:
# Requirement already satisfied: langchain-community in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (0.3.29)
# Collecting langchain-community
#   Downloading langchain_community-0.3.30-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-community) (0.3.76)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-community) (3.12.15)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-community) (0.4.27)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (0.3.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (2.11.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\user\appdata\roaming\python\python310\site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.24.0)
# Requirement already satisfied: anyio in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.10.0)
# Requirement already satisfied: certifi in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\user\appdata\roaming\python\python310\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.30-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 399.0 kB/s eta 0:00:06
#    -------- ------------------------------- 0.5/2.5 MB 399.0 kB/s eta 0:00:06
#    ------------ --------------------------- 0.8/2.5 MB 508.0 kB/s eta 0:00:04
#    ---------------- ----------------------- 1.0/2.5 MB 565.4 kB/s eta 0:00:03
#    ---------------- ----------------------- 1.0/2.5 MB 565.4 kB/s eta 0:00:03
#    ---------------- ----------------------- 1.0/2.5 MB 565.4 kB/s eta 0:00:03
#    -------------------- ------------------- 1.3/2.5 MB 541.1 kB/s eta 0:00:03
#    ------------------------ --------------- 1.6/2.5 MB 582.5 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.8/2.5 MB 666.5 kB/s eta 0:00:02
#    ------------------------------------- -- 2.4/2.5 MB 780.2 kB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 820.8 kB/s  0:00:04
# Installing collected packages: langchain-community
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.3.29
#     Uninstalling langchain-community-0.3.29:
#       Successfully uninstalled langchain-community-0.3.29
# Successfully installed langchain-community-0.3.30

# %% [markdown]
# ### API キーの取得

# %%
from google.colab import userdata
import os

# サイドバーで追加したシークレットを取得
apikey = userdata.get("OPENAI_API_KEY")

# 改行や空白を除去して環境変数に登録
if apikey:
    os.environ["OPENAI_API_KEY"] = apikey.strip()
else:
    raise ValueError("ColabのSecretsに OPENAI_API_KEY が設定されていません")

# %% [markdown]
# ### インポート

# %%
# ===========================================
# セル1: 必要なライブラリのインストール & インポート
# ===========================================
# !pip install langchain openai

from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain

# %% [markdown]
# ### LLM の設定

# %%
# ===========================================
# セル2: モデル準備
# ===========================================
# OpenAI APIを利用したチャットモデルを呼び出し
# temperature=0 → 再現性のある一本道（Single-Path）に向く
# temperatureを上げると候補の幅（Multi-Path）が広がる

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20936\267995697.py:8: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %% [markdown]
# ### Single-Path Plan Generator

# %%
# ===========================================
# セル3: Single-Path Plan Generator
# ===========================================
# 寸劇で「一本道の温泉プラン」を提示したAI
# → ユーザーの要望に対し、最適と思うプランだけを返す

single_prompt = ChatPromptTemplate.from_template(
    "あなたは旅行プランナーです。"
    "ユーザの要望に対し、最適と思う一本道の計画だけを提案してください。\n"
    "要望: {request}"
)

single_chain = LLMChain(llm=llm, prompt=single_prompt)

# 実行例
request = "卒業旅行で箱根を楽しみたい"
single_result = single_chain.run({"request": request})
print("=== Single-Path Plan ===")
print(single_result)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20936\357037267.py:13: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   single_chain = LLMChain(llm=llm, prompt=single_prompt)
# C:\Users\user\AppData\Local\Temp\ipykernel_20936\357037267.py:17: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   single_result = single_chain.run({"request": request})
# === Single-Path Plan ===
# 卒業旅行で箱根を楽しむためのプランを提案します。
#
# ### 箱根卒業旅行プラン
#
# **1日目: 箱根の自然と温泉を満喫**
#
# - **午前中: 箱根湯本駅到着**
#   - 箱根湯本駅に到着後、駅周辺で軽食を楽しむ（名物の温泉まんじゅうなど）。
#
# - **午前: 箱根登山鉄道で強羅へ移動**
#   - 美しい景色を楽しみながら、箱根登山鉄道に乗車。
#
# - **昼食: 強羅でのランチ**
#   - 強羅のレストランで地元の食材を使った料理を楽しむ。
#
# - **午後: 大涌谷観光**
#   - 大涌谷で黒たまごを食べたり、火山活動を見学。
#
# - **夕方: 箱根彫刻の森美術館**
#   - 美術館でアートを楽しみながら、リラックスした時間を過ごす。
#
# - **夜: 温泉宿にチェックイン**
#   - 旅館やホテルで温泉に浸かり、リフレッシュ。夕食は宿の料理を堪能。
#
# ---
#
# **2日目: 箱根の文化と観光を楽しむ**
#
# - **朝: 旅館での朝食**
#   - 旅館の朝食を楽しんだ後、チェックアウト。
#
# - **午前: 箱根神社参拝**
#   - 箱根神社を訪れ、厄除けや学業成就を祈願。
#
# - **昼食: 芦ノ湖周辺でランチ**
#   - 芦ノ湖の景色を楽しみながら、湖畔のレストランでランチ。
#
# - **午後: 芦ノ湖遊覧船**
#   - 芦ノ湖を遊覧船で巡り、湖の美しい景色を堪能。
#
# - **夕方: 箱根湯本駅へ戻る**
#   - 箱根湯本駅に戻り、帰路につく。
#
# ---
#
# このプランで、箱根の自然、文化、温泉を存分に楽しむことができます。素晴らしい卒業旅行をお過ごしください！

# %% [markdown]
# ### Multi-Path Plan Generator

# %%
# ===========================================
# セル4: Multi-Path Plan Generator
# ===========================================
# 寸劇で「候補を複数提示」したAI
# → 複数の異なるプランを返す

multi_prompt = ChatPromptTemplate.from_template(
    "あなたは旅行プランナーです。"
    "ユーザの要望に対し、3〜4種類の異なるプランを提案してください。\n"
    "要望: {request}"
)

multi_chain = LLMChain(llm=llm, prompt=multi_prompt)

# 実行例
multi_result = multi_chain.run({"request": request})
print("=== Multi-Path Plan ===")
print(multi_result)
# Out:
# === Multi-Path Plan ===
# 卒業旅行で箱根を楽しむためのプランを3つご提案します。それぞれ異なるテーマやアクティビティを取り入れていますので、好みに合わせてお選びください。
#
# ### プラン1: 温泉とリラックスプラン
# **日程:** 2泊3日
#
# - **1日目:**
#   - 箱根湯本駅到着後、宿泊先の温泉旅館にチェックイン。
#   - 旅館内で温泉を楽しみ、リラックス。
#   - 夕食は旅館の懐石料理を堪能。
#
# - **2日目:**
#   - 朝食後、箱根登山鉄道で強羅へ移動。
#   - 強羅公園を散策し、アートや自然を楽しむ。
#   - 昼食は強羅のカフェで軽食。
#   - その後、彫刻の森美術館を訪問。
#   - 夕方、再び温泉でリフレッシュ。
#
# - **3日目:**
#   - 朝食後、箱根神社を参拝。
#   - 芦ノ湖で遊覧船に乗り、湖の美しい景色を楽しむ。
#   - 昼食後、箱根湯本でお土産を購入し、帰路へ。
#
# ---
#
# ### プラン2: アクティブ＆アドベンチャープラン
# **日程:** 1泊2日
#
# - **1日目:**
#   - 箱根湯本駅到着後、アスレチック施設「箱根アドベンチャーランド」でアクティビティを楽しむ。
#   - 昼食は近くのレストランで地元の料理を味わう。
#   - 午後は、箱根ロープウェイで大涌谷へ。火山活動を見学し、黒たまごを試食。
#   - 夕方、宿泊先のホテルにチェックイン。
#   - 夜は、近くの居酒屋で地元の食材を使った料理を楽しむ。
#
# - **2日目:**
#   - 朝食後、ハイキングコースを利用して、箱根の自然を満喫。
#   - 昼食は、ハイキング途中のカフェで軽食。
#   - 午後は、箱根の美術館や博物館を訪問。
#   - 夕方、帰路へ。
#
# ---
#
# ### プラン3: 文化と歴史を楽しむプラン
# **日程:** 1泊2日
#
# - **1日目:**
#   - 箱根湯本駅到着後、箱根関所を見学。
#   - 昼食は、箱根湯本の老舗そば屋でそばを楽しむ。
#   - 午後は、箱根の伝統工芸を体験できる「箱根寄木細工」の工房を訪問。
#   - 夕方、宿泊先の旅館にチェックイン。
#   - 夕食は、地元の食材を使った料理を楽しむ。
#
# - **2日目:**
#   - 朝食後、箱根神社を参拝。
#   - 芦ノ湖で遊覧船に乗り、湖の美しい景色を楽しむ。
#   - 昼食は、湖畔のレストランで。
#   - 午後は、箱根の美術館や文化施設を訪問。
#   - 夕方、帰路へ。
#
# ---
#
# これらのプランは、卒業旅行にぴったりのアクティビティやリラックスできる要素を取り入れています。お好みに合わせて選んで、素敵な思い出を作ってください！

# %% [markdown]
# ### まとめ

# %%
# ===========================================
# セル5: まとめ
# ===========================================
# Single-Path → 「迷わず即決」
# Multi-Path → 「選んで合意形成」
# 寸劇のセツコ（選択肢大好き）とフォーム女子（一本道安心）の掛け合いを
# コードで再現して学べる流れ

print("寸劇で学んだ通り、SingleとMultiを状況に応じて使い分けましょう！")
# Out:
# 寸劇で学んだ通り、SingleとMultiを状況に応じて使い分けましょう！
