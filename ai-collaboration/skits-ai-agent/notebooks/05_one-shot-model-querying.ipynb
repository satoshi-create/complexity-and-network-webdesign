# %% [markdown]
# ## 05 One Shot Model Querying 編

# %%
# !pip install langchain==0.3.0 langchain-openai==0.2.0 langgraph==0.2.22 langchain-community pydantic==2.10.6 dotenv faiss-cpu

# %%
from dotenv import load_dotenv
import os

load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGSMITH_API_KEY") # LangSmith 連携用
os.environ["LANGCHAIN_TRACING_V2"] = "true" # トレース有効化
os.environ["TAVILY_API_KEY"] = os.getenv("TAVILY_API_KEY")

# %%
# ============================================================
# セル1: 必要なライブラリのインストールとインポート
# ============================================================

# LangChainのOpenAIラッパーを利用
# pip install langchain-openai が必要です
from langchain_openai import ChatOpenAI

# %%
# ============================================================
# セル2: モデルの準備
# ============================================================

# 軽量で低コストのモデルを選択（gpt-4o-miniなど）
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %%
# ============================================================
# セル3: 情報不足のプロンプト（失敗例）
# ============================================================

# 高速入口でテンパったさとが曖昧に聞く
prompt_bad = "ETCどう使うの？"

response_bad = llm.invoke(prompt_bad)

print("【失敗プロンプト】")
print(prompt_bad)
print("\n【ETC姉の回答】")
print(response_bad.content)
# Out:
# 【失敗プロンプト】
# ETCどう使うの？
#
# 【ETC姉の回答】
# ETC（Electronic Toll Collection）は、日本の高速道路や一部の有料道路で使用される電子料金収受システムです。ETCを利用するための基本的な手順は以下の通りです。
#
# 1. **ETC車載器の取り付け**: 車両にETC車載器を取り付けます。これは専門の業者や自分で取り付けることができます。
#
# 2. **ETCカードの取得**: 銀行やクレジットカード会社からETCカードを申し込みます。このカードは、料金の支払いに使用されます。
#
# 3. **車載器とカードの設定**: 車載器にETCカードを挿入し、設定を行います。多くの場合、車載器は自動的にカードを認識します。
#
# 4. **料金所の通過**: 高速道路の料金所に近づくと、ETC専用レーンに進入します。料金所のゲートが自動で開くので、そのまま通過します。
#
# 5. **料金の支払い**: 通過後、ETCカードに基づいて料金が自動的に引き落とされます。通行料金の明細は、後日ETCカードの利用明細で確認できます。
#
# 6. **利用明細の確認**: ETCカードの利用明細書やオンラインバンキングで、通行料金を確認します。
#
# ETCを利用することで、現金を使わずにスムーズに高速道路を利用できるため、渋滞の緩和にも寄与します。また、ETC割引などの特典もあるため、経済的にもメリットがあります。

# %%
# ============================================================
# セル4: 正しいプロンプト（成功例）
# ============================================================

# 情報をきちんと詰め込んだプロンプト
prompt_good = (
    "ETC初心者です。"
    "高速道路入口で使う方法を3ステップで説明してください。"
    "カードの入れ方・差し込み場所・注意点を含めて、100文字以内で簡潔に。"
)

response_good = llm.invoke(prompt_good)

print("【成功プロンプト】")
print(prompt_good)
print("\n【ETC姉の回答】")
print(response_good.content)
# Out:
# 【成功プロンプト】
# ETC初心者です。高速道路入口で使う方法を3ステップで説明してください。カードの入れ方・差し込み場所・注意点を含めて、100文字以内で簡潔に。
#
# 【ETC姉の回答】
# 1. ETCカードを用意し、高速道路入口のETCレーンに進入。
# 2. カードを挿入口に差し込み、ICチップを下向きに。
# 3. 通過時にカードを抜かず、ゲートが開くのを待つ。注意：通行後はカードを確認。
