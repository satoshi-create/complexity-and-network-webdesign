# %% [markdown]
# # # Proactive Goal Creator 編

# %%
# !pip install langchain==0.3.0 langchain-openai==0.2.0 langgraph==0.2.22 pydantic==2.10.6 dotenv

# %%
from dotenv import load_dotenv
import os

load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGSMITH_API_KEY") # LangSmith 連携用
os.environ["LANGCHAIN_TRACING_V2"] = "true" # トレース有効化
os.environ["TAVILY_API_KEY"] = os.getenv("TAVILY_API_KEY")

# %%
# Step 1: 必要ライブラリのインポート
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain_openai import ChatOpenAI

# %%
# Step 2: LLMの初期化
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)

# %%
# Step 3: Proactive Goal Creator のプロンプト定義
# ユーザーの依頼が曖昧でも、AIが「潜在的に必要なゴール」を3つ提案します。

template = """あなたは Proactive Goal Creator です。
ユーザーの依頼が曖昧な場合、潜在的に必要となるゴールを3つ提案してください。

ユーザー依頼: {request}
"""

prompt = PromptTemplate.from_template(template)
chain = LLMChain(llm=llm, prompt=prompt)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17288\1285933169.py:11: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(llm=llm, prompt=prompt)

# %%
# Step 4: 実行してみる
# 例: 「新規事業のアイデアを出して」という曖昧な依頼を投げます。
request = "新規事業のアイデアを出して"
result = chain.run(request)
print("🔮 Proactive Goal Creator の提案:\n")
print(result)

# ✅ このように曖昧な依頼をすると、AIが「市場調査」「ユーザーインタビュー」「試作品テスト」などの
# ゴール候補を自動的に生成します。
# これが Proactive Goal Creator の基本的な流れです。
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17288\1742107143.py:4: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = chain.run(request)
# 🔮 Proactive Goal Creator の提案:
#
# 新規事業のアイデアを出すために、以下の3つのゴールを提案します：
#
# 1. **市場調査とニーズ分析の実施**
#    新規事業のアイデアを考える前に、ターゲット市場のニーズやトレンドを把握するための調査を行います。競合分析や消費者インタビューを通じて、どのような商品やサービスが求められているかを明らかにすることが重要です。
#
# 2. **アイデアブレインストーミングセッションの開催**
#    チームメンバーや関係者を集めて、自由な発想でアイデアを出し合うブレインストーミングセッションを実施します。このセッションでは、異なる視点や専門知識を持つ人々の意見を取り入れ、多様なアイデアを生成することを目指します。
#
# 3. **プロトタイプの作成とフィードバックの収集**
#    アイデアが固まったら、初期のプロトタイプやサービスモデルを作成し、実際のユーザーからのフィードバックを収集します。これにより、アイデアの実現可能性や市場での受け入れられ方を検証し、必要に応じて修正を加えることができます。
